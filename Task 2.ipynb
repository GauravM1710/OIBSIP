# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

df = pd.read_csv(r"C:\Users\asus\Desktop\archive (1)\Unemployment in India.csv")
print(df.head())
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
print(df.isnull().sum())
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df.columns = ["Region", "Date", "Frequency", "Estimated Unemployment Rate (%)",
                "Estimated Employed", "Estimated Labour Participation Rate (%)", "Area"]

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr())
plt.show()

# %%
corr=df.corr()
sns.heatmap(corr,cmap='coolwarm',annot=True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
plt.hist(df['Estimated Unemployment Rate (%)'],bins=18)
plt.title('Histogram for Estimated Unemployment Rate (%)')
# Out:
# Text(0.5, 1.0, 'Histogram for Estimated Unemployment Rate (%)')

# %%
plt.hist(df['Estimated Labour Participation Rate (%)'],bins=18)
plt.title('Histogram for Estimated Labour Participation Rate (%)')
# Out:
# Text(0.5, 1.0, 'Histogram for Estimated Labour Participation Rate (%)')

# %%
df.columns = ["Region", "Date", "Frequency", "Estimated Unemployment Rate (%)",
                "Estimated Employed", "Estimated Labour Participation Rate (%)", "Area"]
plt.title("Indian Unemployment")
sns.histplot(x="Estimated Employed", hue="Region", data=df)
plt.show()

# %%
df = pd.read_csv(r"C:\Users\asus\Desktop\archive (1)\Unemployment in India.csv")
# Print the column names to check for any discrepancies
print(data.columns)
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 10))
plt.title("Indian Unemployment")
sns.displot(data=df,x="Estimated Unemployment Rate (%)",hue="Region",kde=True)
plt.show()

# %%
# Read the data and rename columns (if needed)
df = pd.read_csv(r"C:\Users\asus\Desktop\archive (1)\Unemployment in India.csv")
df.columns = ["Region", "Date", "Frequency", "Estimated Unemployment Rate (%)",
                "Estimated Employed", "Estimated Labour Participation Rate (%)", "Area"]

# Filter and group the data for the Sunburst chart
unemployment = df.groupby(["Region", "Area"], as_index=False)["Estimated Unemployment Rate (%)"].mean()

# Generate the Sunburst chart
figure = px.sunburst(unemployment, path=["Region", "Area"], 
                     values="Estimated Unemployment Rate (%)", 
                     width=700, height=700, color_continuous_scale="RdYlGn", 
                     title="Unemployment Rate in India")

figure.show()
# Out:
# <div>                            <div id="3264710f-a415-4e20-8571-ef92caf5455b" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3264710f-a415-4e20-8571-ef92caf5455b")) {                    Plotly.newPlot(                        "3264710f-a415-4e20-8571-ef92caf5455b",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eEstimated Unemployment Rate (%)=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Andhra Pradesh\u002fRural","Assam\u002fRural","Bihar\u002fRural","Chhattisgarh\u002fRural","Delhi\u002fRural","Goa\u002fRural","Gujarat\u002fRural","Haryana\u002fRural","Himachal Pradesh\u002fRural","Jammu & Kashmir
# ...
